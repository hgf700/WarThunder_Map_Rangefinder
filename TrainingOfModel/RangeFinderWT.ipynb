# %%
pip install ultralytics

# %%
# !pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install --upgrade ultralytics

# %%
# Ctrl + M, potem B → nowa komórka poniżej
# Ctrl + M, potem A → nowa komórka powyżej

# %%
# !nvidia-smi
# Out:
# Wed Oct 22 04:46:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
import shutil
shutil.copytree('/drive/MyDrive/TrainingData', '/content/TrainingData')
# Out:
# '/content/TrainingData'

# %%
from zipfile import ZipFile
from google.colab import files
import os

folder_path = "/content/runs/train_yolo_wt"
zip_path = "/content/train_yolo_wt.zip"

with ZipFile(zip_path, 'w') as zipf:
    for root, dirs, files_in_dir in os.walk(folder_path):
        for file in files_in_dir:
            file_path = os.path.join(root, file)
            zipf.write(file_path, os.path.relpath(file_path, folder_path))

files.download(zip_path)

# %%
from ultralytics import YOLO
from zipfile import ZipFile
from google.colab import files
import os

model = YOLO("yolov8n.pt")
model.train(
    data="/content/TrainingData/data.yaml",
    epochs=200,
    imgsz=640,
    device=0,
    batch=8,
    half=True,
    augment=True,
    cache=True,
    patience=20,
    save_period=10,
    save_txt=True,
    save=True,
    name="train_yolo_wt1",
    project="/content/runs"
)

folder_path = "/content/runs/train_yolo_wt"
zip_path = "/content/train_yolo_wt.zip"

with ZipFile(zip_path, 'w') as zipf:
    for root, dirs, files_in_dir in os.walk(folder_path):
        for file in files_in_dir:
            file_path = os.path.join(root, file)
            zipf.write(file_path, os.path.relpath(file_path, folder_path))

files.download(zip_path)
# Out:
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
